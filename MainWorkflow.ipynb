# %% [markdown]
# # Functional analysis of post-translationally modified protein complexes
#
# We will analyze the quantitative behavior of protein complexes with respect to the post-translational modifications of
# their proteins. This allows identifying different functional behavior of different proteoforms and complex composition directed by signalling events in the differentiating cells.
#
# Quantitative proteomics data usually comes from bottom-up LC-MS (liquid chromatography mass spectrometry) experiments, where the proteins are digested into peptides prior to data acquisition. This means that we have to go from the peptide to the protein level.
#
# As data example, you will use the experimental data from an investigation of molecular signaling networks activated during muscle formation by Christina Erika Hagensen et. al (unpublished study). The study is started with human satellite cells. These are resting muscle cells, that can be activated and developed into mature muscle cells e.g. when muscles are damaged. When activated, the satellite cells divide and produce myoblasts that futher proliferate and fuse into myotubes which later mature into myofibers. This process is driven by signalling events leading to the necessary changes in  the transcriptional programme, cell behavior and morphology.
#
# The samples were measured in triplicates for each of the 6 times points as given in the following picture.
#
# ![Muscle time study](Muscle_Time_study.JPG)

# %% [markdown]
# ### General instructions
#
# You will go through the different cells of the workflow below. Execute the cells by pressing "shift-enter" or clicking on the triangle on the top.
#
# For giving the answers to the questions below, double-click on the Jupyter cell, and add them at the given position.
#
# 👨‍💻 Start with running the following cell (only once)

# %%
# Some preparations like installing and loading libraries. Run only once
#install.packages(c("gplots", "lattice"))
library(gplots)
library(lattice)
options(repr.plot.width=12, repr.plot.height=8)

# %% [markdown]
# ### Load basic data structure
#
# 👨‍💻 Load the expression profiles of complexes, proteins and modified peptides (phosphorylations and acetylations).
#
# This data structure is the result of a full data analysis workflow to extract the quantitative changes from hundreds of thousands of mass spectra, each of them providing information about a specific peptide.
#
# Protein and complex expression changes were calculated by summarizing expression changes of unmodified peptides.

# %%
complexes <- readRDS("complex_structure.RData")

# %% [markdown]
# #### Protein complexes
#
# The data is arranged into known protein complexes from the CORUM data base (https://mips.helmholtz-muenchen.de/corum/). Proteins not forming a complex are not considered here.

# %%
length(complexes)

# %% [markdown]
# #### Add your answers here
# (double-click here to edit the cell)
#
# ##### ❔ Question I:  <ins>What is a protein complex and why are they important? Given an example for a complex. </ins>
#
# _Answer_
#
# ##### ❔ Question II:  <ins>How many human complex are annotated in the CORUM database? How many are given in the data structure?</ins>
#
# _Answer_

# %% [markdown]
# ### Selecting an example protein complex
#
# 💡 You can check for different names that match a pattern like "olyco" or paste a complex name from the list given in the last cell in this notebook.
#
# 👨‍💻 Let's take the "Polycomb repressive complex" (PRC1). It catalyses monoubiquitination
# of histone H2A on Lys119, promoting gene silencing.
#
# We expect it to change during differentiation as the transcriptional programme is broadly affected.

# %%
grep("olycom", names(complexes),value=T)
cname <- "Polycomb repressive complex"

# %% [markdown]
# #### Add your answers here
# (double-click here to edit the cell)
#
# ##### ❔ Question I:  <ins>Why are there massive changes in gene transcription?</ins>
#
# _Answer_
#
# ##### ❔ Question II:  <ins>Any idea why there are different forms of the same complex?</ins>
#
# _Answer_

# %% [markdown]
# ### Workflow for visual complex analysis
#
# #### Step 1: available information
#
# 👨‍💻 Get an idea of the available protein and peptide expressions of this complex

# %%
PComplex <- complexes[cname][[1]]
names(PComplex)

#Protein subunits of the complex
PComplex$Composition
# number of peptides per subunit
names(PComplex$PTMs_Raw) <- PComplex$Composition
lapply(PComplex$PTMs_Raw, nrow)

# %% [markdown]
# #### Add your answers here
# (double-click here to edit the cell)
#
# ##### ❔ Question I:  <ins>How many proteins does this complex contain?</ins>
#
# _Answer_
#
# ##### ❔ Question II:  <ins>What does a code like "P78364" denote? Where do you get more information about this?</ins>
#
# _Answer_
#
# ##### ❔ Question III:  <ins>How many proteins of the complex were found in the experiment?</ins>
#
# _Answer_

# %% [markdown]
# #### Step 2: Protein analysis
#
# 👨‍💻 Extract the protein expression patterns and average them over the three replicates.
#
# Protein expressions are calculated from the quantitative behavior of their non-modified peptides. This procedure is call protein inference (for finding the contributing peptides) and protein summarization (for extracting the protein changes from the individual changes in peptide expression).

# %%
Prots <- PComplex$Proteins[,2:ncol(PComplex$Proteins)]
rownames(Prots) <- PComplex$Proteins[,1]
avProts <- NULL
for(i in 1:6) avProts <- cbind(avProts,rowMeans(Prots[,(i-1)*3+1:3], na.rm=T))
avComplex <- sapply(1:6, function(i) mean(PComplex$Complex[(i-1)*3+1:3], na.rm=T))

# %% [markdown]
# 👨‍💻 Visualize all replicated values and their averages for the proteins of the complex.

# %%
cols <- rainbow(nrow(Prots), alpha = 0.5)
plot(rep(-1:4, each=3), t(Prots[1,]), xaxt="n", xlab="Day after initiation", ylab="relative log-abundance", 
     pch=15, col=cols[1], cex=0.5, ylim=range(Prots, na.rm=T), main=cname)
axis(1, at = -1:4, labels=-1:4)
for (i in 2:nrow(Prots)) {
    points(rep(-1:4, each=3), t(Prots[i,]), pch=15, col=cols[i], cex=0.5)
}
for (i in 1:nrow(avProts)) {
    points(-1:4, t(avProts[i,]), pch=16, col=cols[i], cex=1, type="b")
}
lines(-1:4, avComplex, lwd=2)
legend("bottomleft", legend = c(rownames(Prots), "Complex"), fill=c(cols,"#000000"), border=0,cex=1)

# %% [markdown]
# 👨‍💻 Alternatively, plot the average profiles using the `heatmap` function to cluster the proteins
# according to similarities in their expression profiles
#
# This does not make much sense for only 3 proteins but is more insightful for larger complexes.

# %%
tmax <- max(abs(avProts), na.rm=T)
heatmap.2(as.matrix(avProts), scale="none", labCol = paste("Day", -1:4), main=cname,
          breaks = seq(-tmax, tmax, length=101),cexRow = 1,
          col=redblue(100), trace="none", dendrogram = "row", Colv = "none")

# %% [markdown]
# #### Add your answers here
# (double-click here to edit the cell)
#
# ##### ❔ Question I:  <ins>What general trend do you observe?</ins>
#
# _Answer_
#
# ##### ❔ Question II:  <ins>Do you think the proteins of the complex have other roles in the cell than forming the complex?</ins>
#
# _Answer_

# %% [markdown]
# #### Step 3: PTM analysis
#
# 👨‍💻 Extract the modified peptides of the proteins and average them over replicates.
#
# They can show vastly different behavior and often provide information about regulated, different protein and complex functions

# %%
# Get the peptide table and average over replicates
ModPeps <- NULL
for (peps in PComplex$PTMs_Raw) {
  ModPeps <- rbind(ModPeps, peps)
}
avModPeps <- NULL
  for(i in 1:6) avModPeps <- cbind(avModPeps,rowMeans(ModPeps[,3+(i-1)*3+1:3], na.rm=T))
rownames(avModPeps) <- ModPeps[,1]

# %% [markdown]
# 👨‍💻 Again, plot the expression profiles of both replicates and averages.

# %%
cols <- rainbow(nrow(ModPeps), alpha = 0.5)
prots <- names(table(ModPeps[,3]))
print(prots)
plot(rep(-1:4, each=3), t(ModPeps[1,4:ncol(ModPeps)]), xaxt="n", xlab="Day after initiation", ylab="relative log-abundance", 
     pch=1, col=cols[1], cex=0.5, ylim=range(ModPeps[,4:ncol(ModPeps)], na.rm=T), main=cname)
axis(1, at = -1:4, labels=-1:4)
for (i in 2:nrow(ModPeps)) {
    points(rep(-1:4, each=3), t(ModPeps[i,4:ncol(ModPeps)]), pch=which(prots == ModPeps[i,3]), col=cols[i], cex=0.5)
}
for (i in 1:nrow(avModPeps)) {
    points(-1:4, t(avModPeps[i,]), pch=which(prots == ModPeps[i,3]), col=cols[i], cex=1, type="b")
}
legend("bottomleft", legend = c(ModPeps[,1]), fill=c(cols), cex=0.5, border=0)

# %% [markdown]
# Given the large number of peptides, this becomes very fast very messy.
#
# 👨‍💻 Use hierarchical clustering that helps by ordering
# the peptides according to their quantitative behavior

# %%
tmax <- max(abs(avModPeps), na.rm=T)
heatmap.2(as.matrix(avModPeps),dendrogram="row", scale="none", main=paste0(cname,"\nmodified peptides"), labRow = ModPeps[,1], 
          labCol=paste("Day",-1:4), offsetRow=-0.6, srtRow=60, Colv = "none",
          cexRow = 0.7, trace = "none", breaks=seq(-tmax, tmax, length=101), col = redblue(100))

heatmap.2(as.matrix(rbind(avModPeps,avProts)), dendrogram="row", scale="none", cexRow = 0.7, 
          trace = "none", breaks=seq(-tmax, tmax, length=101), col = redblue(100),Colv = "none",
          labCol = paste("Day", -1:4), main=paste0(cname, "\nproteins and modified peptides"), offsetRow=-0.6, srtRow=60,)

# %% [markdown]
# #### Add your answers here
# (double-click here to edit the cell)
#
# ##### ❔ Question I:  <ins>What are the main trends? How do the proteins behave in comparison to modified peptides? </ins>
#
# _Answer_
#
# ##### ❔ Question II:  <ins>Modified peptide measurements are much more variant. Why would that be? Think about both biological and technical reasons.</ins>
#
# _Answer_
#
# ##### ❔ Question III:  <ins>There is one particular peptide coming in different forms. Which is it and what could that mean?</ins>
#
# _Answer_

# %% [markdown]
# When it comes to larger complexes with more than 10 proteins and plenty of PTMs on their subunits, the visualizations above are not very informative. We can use pairwise correlations to get a better idea of co-regulations between proteins and modified peptides
#
# 👨‍💻 Create a correlation matrix and plot it with the `heatmap` function.
#
# The following plot contains many details, so take you time to understand the different components. As each of the modified peptides corresponds to one of the protein subunits, this relation is given both as color and in the labels.

# %%
allprots <- c(rownames(avProts), ModPeps[,3])
print(avModPeps)
heatmap.2(cor(t(rbind(avProts,avModPeps))),symm = T,trace="none",labRow = c(rownames(avProts), rownames(avModPeps)),labCol = c(rownames(avProts), paste0("mod",ModPeps[,3])),
          breaks=seq(-1,1,0.01),col=redblue, RowSideColors=c(rep("#222222",nrow(avProts)), rep("#BBBBBB",nrow(avModPeps))),
          ColSideColors = rainbow(length(unique(allprots)))[as.factor(allprots)], srtCol = 45, offsetRow=-0.6, srtRow=60)
legend(0.8,1.2, fill=c("#222222","#BBBBBB","#FFFFFF"), legend = c("modified peptide", "protein", "color: corresponding protein"), border=0, cex=1, xpd=T)

# %% [markdown]
# #### Add your answers here
# (double-click here to edit the cell)
#
# ##### ❔ Question I:  <ins>Do you see any particular trends for the modified peptides of the same protein?</ins>
#
# _Answer_
#
# ##### ❔ Question II:  <ins>Which information in the plot do you find most interesting? And how much do you trust it to be true?</ins>
#
# _Answer_

# %% [markdown]
# ### Other complexes
#
# 👨‍💻 Now, select other complexes from the list below and run the workflow above again after changing the complex name when defining `cname`. Check whether there have been measured more than one proteins as it will fail otherwise.
#
# Also try larger complexes like the ribosome and the proteasome.
#
# 👨‍💻 __Write down three main impression/results for each of the selected complexes__. Read about the complex in the literature and/or on CORUM and UniProt.
#
# _Answers:_
#
# Complex name:<br/>
#    Result 1: <br/>
#    Result 2: <br/>
#    Result 3: <br/>
#
# Complex name:<br/>
#    Result 1: <br/>
#    Result 2: <br/>
#    Result 3: <br/>
#
# Complex name:<br/>
#    Result 1: <br/>
#    Result 2: <br/>
#    Result 3: <br/>

# %%
print(sort(names(complexes)))
# Out:
#    [1] "(E.F.G) complex"
#    [2] "12S U11 snRNP"
#    [3] "14-3-3 gamma-CXCR2 complex, unstimulated"
#    [4] "17S U2 snRNP"
#    [5] "18S U11/U12 snRNP"
#    [6] "20S methylosome and RG-containing Sm protein complex"
#    [7] "20S methylosome-SmD complex"
#    [8] "20S methyltransferase core complex"
#    [9] "20S proteasome"
#   [10] "26S proteasome"
#   [11] "28S ribosomal subunit, mitochondrial"
#   [12] "39S ribosomal subunit, mitochondrial"
#   [13] "3M complex"
#   [14] "3M core complex"
#   [15] "40S ribosomal subunit, cytoplasmic"
#   [16] "4E-T-DDX6-CNOT1 complex"
#   [17] "53BP1-containing complex"
#   [18] "55S ribosome, mitochondrial"
#   [19] "5FMC (Friends of Methylated Chtop) complex"
#   [20] "5S-DNA-TFIIIA-TFIIIC2 subcomplex"
#   [21] "5S-DNA-TFIIIA-TFIIIC2-TFIIIB subcomplex"
#   [22] "60S APC containing complex"
#   [23] "60S ribosomal subunit, cytoplasmic"
#   [24] "6S methyltransferase and RG-containing Sm proteins complex"
#   [25] "6S methyltransferase complex"
#   [26] "9-1-1 complex"
#   [27] "9-1-1-APE1 complex"
#   [28] "9-1-1-FEN1 complex"
#   [29] "9-1-1-LIG1 complex"
#   [30] "9-1-1-POLB complex"
#   [31] "9-1-1-RAD17-RFC complex"
#   [32] "9-1-1-RHINO complex"
#   [33] "9b-1-1 complex"
#   [34] "ABIN2-NFKB1-MAP3K8 complex"
#   [35] "ACAP1-CHC-Glut4 complex"
#   [36] "ACK1 signaling complex"
#   [37] "ACT-CREB complex"
#   [38] "Actin-ribonucleoprotein complex (POLR2A, GTF2F1, HNRNPU)"
#   [39] "ADAR1-CDK2 complex"
#   [40] "ADRB2 homodimer complex"
#   [41] "AFF4 super elongation complex (SEC)"
#   [42] "Affixin-actinin(alpha) complex"
#   [43] "AGO2-FXR1-TNF(alpha)ARE-RNP complex"
#   [44] "AGPS-GNPAT complex"
#   [45] "AHI1-HAP1 complex"
#   [46] "AHI1-NPHP1 heterodimer"
#   [47] "AHI1-NPHP1 heterotetramer"
#   [48] "AIF-CYPA-DNA complex"
#   [49] "AJUBA-GFI1-HDAC1 complex"
#   [50] "AJUBA-GFI1-HDAC2 complex"
#   [51] "AJUBA-GFI1-HDAC3 complex"
#   [52] "AKAP250-PKA-PDE4D complex"
#   [53] "Akt-PHLPP1-PHLPP2-FANCI-FANCD2-USP1-UAF1 complex"
#   [54] "ALL-1 supercomplex"
#   [55] "AMY-1-S-AKAP84-RII-beta complex"
#   [56] "Amyloid beta protein oligomer"
#   [57] "Anaphase-promoting complex"
#   [58] "ANCO1-HDAC3  complex"
#   [59] "Angiogenin-PRI complex"
#   [60] "ANKRA2-CCDC8-OBSL1-CUL7 complex"
#   [61] "ANKS6-NEK8-INVS-NPHP3 complex"
#   [62] "anti-BHC110 complex"
#   [63] "Anti-HDAC2 complex"
#   [64] "Anti-Sm protein complex"
#   [65] "AP1 adaptor complex"
#   [66] "AP1G1-PACS1-FURIN complex"
#   [67] "AP3 adaptor complex"
#   [68] "AP3-BLOC1 complex"
#   [69] "AP4 adaptor complex"
#   [70] "AP5 adaptor complex"
#   [71] "AP5-SPG11-SPG15 complex"
#   [72] "APC-Axin-1-beta-catenin complex"
#   [73] "APLG1-Rababtin5 complex"
#   [74] "APOL1 complex A (APOL1, APOA1, HPR, C3)"
#   [75] "APOL1 complex B (APOL1, APOA1, HPR, FN1, IGHM)"
#   [76] "Apoptosis- and splicing-associated protein complex (ASAP-S), SAP18, RNPS1, Acinus-S"
#   [77] "Apoptosome"
#   [78] "Apoptosome-procaspase 9 complex"
#   [79] "APP-FE65-LRP complex"
#   [80] "APP-TIM23 complex"
#   [81] "APP-TOM40 complex"
#   [82] "AR-AKT-APPL complex"
#   [83] "ARC complex"
#   [84] "ARC complex"
#   [85] "ARC-L complex"
#   [86] "ARC92-Mediator complex"
#   [87] "ARD1-NATH complex"
#   [88] "ARF-Mule complex"
#   [89] "ARL2-TBCD complex"
#   [90] "ARNT-HIF1A complex"
#   [91] "Arp2/3 complex"
#   [92] "ARP3-WHAMM complex"
#   [93] "Artemis-DNA-PK complex"
#   [94] "ASCOM complex"
#   [95] "ASF1-histone containing complex"
#   [96] "ASF1-interacting protein complex"
#   [97] "ASPP1-SAM68 complex"
#   [98] "ATAC complex, GCN5-linked"
#   [99] "ATAC complex, YEATS2-linked"
#  [100] "ATF4-CREB1 complex"
#  [101] "ATL2-SPG31 complex"
#  [102] "ATL2-SPG33 complex"
#  [103] "ATL3-SPG31 complex"
#  [104] "ATL3-SPG33 complex"
#  [105] "ATM homodimer complex"
#  [106] "ATM-NBS1 complex"
#  [107] "ATR-ATRIP complex"
#  [108] "ATR-HDAC2 complex"
#  [109] "ATR-HDAC2-CHD4 complex"
#  [110] "ATRX-DAXX complex"
#  [111] "AURKA-HDAC6 cilia-disassembly complex"
#  [112] "AURKA-INPP5E complex"
#  [113] "AXIN-APC-betaCatenin-GSK3B complex"
#  [114] "AXIN-MEKK4-CCD1 complex"
#  [115] "Axin-PP2A A-PP2A C-GSK3-beta-beta-catenin complex"
#  [116] "Axin-SMAD3 complex"
#  [117] "B-WICH complex"
#  [118] "B-WICH complex"
#  [119] "BAF complex"
#  [120] "BAF complex"
#  [121] "BAFL-BAF complex"
#  [122] "BAFL-BAF-LAP2beta complex"
#  [123] "BAG1-HSC70 complex"
#  [124] "BAG1-HSP70 complex"
#  [125] "BAR-BCL2-CASP8 complex"
#  [126] "BARD1-BRCA1-CSTF complex"
#  [127] "BARD1-BRCA1-CSTF64 complex"
#  [128] "BASC complex (BRCA1-associated genome surveillance complex)"
#  [129] "BBS-chaperonin complex"
#  [130] "BBS4 centriolar satellite complex"
#  [131] "BBSome"
#  [132] "BBSome core complex"
#  [133] "Bcl-2-Beclin1-UVRAG-PI(3)KC3 complex"
#  [134] "BCL10 oligomer complex"
#  [135] "BCL10-MALT1 complex"
#  [136] "BCL6-HDAC4 complex"
#  [137] "BCL6-HDAC5 complex"
#  [138] "BCL6-HDAC7 complex"
#  [139] "BCOR complex"
#  [140] "BCR-ABL (p185 fusion protein)-GRB2 complex"
#  [141] "BCR-ABL (p210 fusion protein)-GRB2-SOS1 complex"
#  [142] "Beta-dystroglycan-caveolin-3 complex"
#  [143] "beta(1)-AR receptosome (ADRB1-SAP97-AKAP79-PRKAR2A)"
#  [144] "BHC complex"
#  [145] "Binary COG subcomplex"
#  [146] "Bipartite complex (TFC4, CTNNB1)"
#  [147] "BIRC5-AURKB-INCENP-EVI5 complex"
#  [148] "BKCA-beta2AR complex"
#  [149] "BKCA-beta2AR-AKAP79 signaling complex"
#  [150] "BLM complex II"
#  [151] "BLM complex III"
#  [152] "BLM-RAD51L3-XRCC2 complex"
#  [153] "BLM-TOP3A complex"
#  [154] "BLM-TRF2 complex"
#  [155] "BLM-TRF2 complex"
#  [156] "BLOC-1 (biogenesis of lysosome-related organelles complex 1)"
#  [157] "BLOC-2 (biogenesis of lysosome-related organelles complex 2)"
#  [158] "BLOC1-BLOC2 complex"
#  [159] "BMI1-HPH1-HPH2 complex"
#  [160] "BP-SMAD complex"
#  [161] "BRAF-MAP2K1-MAP2K2-YWHAE complex"
#  [162] "BRAF-RAF1-14-3-3 complex"
#  [163] "BRAF53-BRCA2 complex"
#  [164] "BRAFT complex"
#  [165] "BRCA1 A complex"
#  [166] "BRCA1 B complex"
#  [167] "BRCA1 C complex"
#  [168] "BRCA1-BACH1 complex"
#  [169] "BRCA1-BARD1-BACH1-DNA damage complex I"
#  [170] "BRCA1-BARD1-BACH1-DNA damage complex II"
#  [171] "BRCA1-BARD1-BRCA2-DNA damage complex III"
#  [172] "BRCA1-BARD1-POLR2A complex"
#  [173] "BRCA1-BARD1-UbcH5c complex"
#  [174] "BRCA1-BARD1-UbcH7c complex"
#  [175] "BRCA1-cABL complex"
#  [176] "BRCA1-core RNA polymerase II complex"
#  [177] "BRCA1-CtIP-CtBP complex"
#  [178] "BRCA1-CTIP-ZBRK1 repressor complex"
#  [179] "BRCA1-HDAC1-HDAC2 complex"
#  [180] "BRCA1-LMO4-CTIP complex"
#  [181] "BRCA1-RAD50-MRE11-NBS1 complex"
#  [182] "BRCA1-RAD51 complex"
#  [183] "BRCA1-RNA polymerase II complex"
#  [184] "BRCA1-SMAD3 complex"
#  [185] "BRCA1-VCP complex"
#  [186] "BRCC complex"
#  [187] "BRD4 complex"
#  [188] "BRD4-P-TEFb complex"
#  [189] "BRD4-RFC complex"
#  [190] "BRG1-SIN3A complex"
#  [191] "BRM-SIN3A complex"
#  [192] "BRM-SIN3A-HDAC complex"
#  [193] "BRMS1-SIN3-HDAC complex"
#  [194] "C complex spliceosome"
#  [195] "c-Abl-CAS-Abi1 complex"
#  [196] "c-Abl-cortactin-nmMLCK complex"
#  [197] "C-CFTR-NHERF-ezrin complex"
#  [198] "c-MYC-ATPase-helicase complex"
#  [199] "CAK complex (Cdk-activating kinase complex)"
#  [200] "CAK-ERCC2 complex"
#  [201] "Calcineurin"
#  [202] "Calcineurin-FKBP12 complex"
#  [203] "CALM1-FKBP38-BCL2 complex"
#  [204] "Calpain 1"
#  [205] "Calreticulin oligomer complex"
#  [206] "CAND1-CUL1-RBX1 complex"
#  [207] "CAND1-CUL2-RBX1 complex"
#  [208] "CAND1-CUL3-RBX1 complex"
#  [209] "CAND1-CUL4A-RBX1 complex"
#  [210] "CAND1-CUL4B-RBX1 complex"
#  [211] "CAP-cbl-flotilin complex"
#  [212] "CAP(C)-CAP(E) complex"
#  [213] "CAPN1-HSP90AB1 complex"
#  [214] "CAPZalpha-CAPZbeta complex"
#  [215] "CARMA1-BCL10-MALT1 complex"
#  [216] "CART complex"
#  [217] "CAS-SRC-FAK complex"
#  [218] "Casein kinase II (beta-dimer, alpha-dimer)"
#  [219] "Casein kinase II (beta-dimer, alpha'-dimer)"
#  [220] "Casein kinase II complex"
#  [221] "Casein kinase II-HMG1 complex"
#  [222] "CASK-LIN7C-APBA1 complex"
#  [223] "Catenin (alpha) - catenin (beta) complex"
#  [224] "Catulin (alpha) - catenin (beta) complex"
#  [225] "CAV1-VDAC1-ESR1 complex"
#  [226] "CBC complex (cap binding complex)"
#  [227] "CBF-DNA complex"
#  [228] "CBF1-HDAC1-SMRT complex"
#  [229] "Cbl-SLP-76-Grb2 complex, Fc receptor gamma-R1 stimulated"
#  [230] "CBP-RARA-RXRA-DNA complex, ligand stimulated"
#  [231] "CC2D2A-CEP290 complex"
#  [232] "CCC complex"
#  [233] "CCC-Wash (WASH1, FAM21C) multiprotein complex"
#  [234] "CCDC22-COMMD1-CUL2 complex"
#  [235] "CCDC22-COMMD8-CUL1 complex"
#  [236] "CCDC22-COMMD8-CUL3 complex"
#  [237] "CCDC92-CEP164 complex"
#  [238] "CCNB1-CDC2 complex"
#  [239] "CCNB2-CDC2 complex"
#  [240] "CCND1-CDK4 complex"
#  [241] "CCND1-CDK6 complex"
#  [242] "CCND2-CDK4 complex"
#  [243] "CCND2-CDK6 complex"
#  [244] "CCND3-CDK4 complex"
#  [245] "CCND3-CDK6 complex"
#  [246] "CCP110-CEP290 complex"
#  [247] "CCR4-NOT complex"
#  [248] "CD147-gamma-secretase complex (APH-1a, PS-1, PEN-2, NCT variant)"
#  [249] "CD19-Vav-PI 3-kinase (p85 subunit) complex"
#  [250] "CD20-LCK-LYN-FYN-p75/80 complex, (Raji human B cell line)"
#  [251] "CD28-transactivation complex"
#  [252] "CD98-LAT2-ITGB1 complex"
#  [253] "CDC2-CCNA2 complex"
#  [254] "CDC2-CCNA2-CDK2 complex"
#  [255] "CDC2-CCNB1-CCNF complex"
#  [256] "CDC2-CCNB1-PTCH1 complex"
#  [257] "CDC2-PCNA-CCNB1-GADD45A complex"
#  [258] "CDC2-PCNA-CCNB1-GADD45B complex"
#  [259] "CDC2-PCNA-CCNB1-GADD45G complex"
#  [260] "CDC5L complex"
#  [261] "CDC5L core complex"
#  [262] "CDH1-CKS1B complex"
#  [263] "CDH1-SKP2 complex"
#  [264] "CDK2-CCNA2 complex"
#  [265] "CDK2-CCNE1 complex"
#  [266] "CDK8-CyclinC-Mediator complex"
#  [267] "CEBPE-E2F1-RB1 complex"
#  [268] "Cell cycle kinase complex CDC2"
#  [269] "Cell cycle kinase complex CDK2"
#  [270] "Cell cycle kinase complex CDK4"
#  [271] "Cell cycle kinase complex CDK5"
#  [272] "Cell division cycle complex (CDC27, CDC16, ANAPC7)"
#  [273] "Cell-cell junction complex (ARHGAP10-CTNNA1)"
#  [274] "Cell-cell junction complex (CDH1-CTNNB1)"
#  [275] "CEN complex"
#  [276] "CENP-A NAC-CAD complex"
#  [277] "CENP-A nucleosome associated complex"
#  [278] "CEP290-IQCB1 complex"
#  [279] "CERF complex (CECR2-containing remodeling factor complex)"
#  [280] "CF IIAm complex (Cleavage factor IIAm complex)"
#  [281] "CFTR-NHERF-beta(2)AR signaling complex"
#  [282] "Channel complex TRPM6-TRPM7"
#  [283] "Chromatin assembly complex (CAF-1 complex)"
#  [284] "Chromatin remodeling complex (TACC2, TACC3, PCAF)"
#  [285] "Chromosomal passenger complex CPC (INCENP, BIRC5, AURKB)"
#  [286] "Chromosomal passenger complex CPC (INCENP, CDCA8, BIRC5, AURKB)"
#  [287] "CHTOP-methylosome complex"
#  [288] "CHUK-IQGAP2-AKAP8L-RELA-TNIP2 complex"
#  [289] "CHUK-NFKB2-REL-IKBKG-SPAG9-NFKB1-NFKBIE-COPB2-TNIP1-NFKBIA-RELA-TNIP2 complex"
#  [290] "CIN85 homotetramer complex"
# ...
# [1523] "Ubiquitin E3 ligase (CRY2, SKP1A, CUL1, FBXL3)"
# [1524] "Ubiquitin E3 ligase (CSN1, CSN8, HRT1, SKP1, SKP2, CUL1, CUL2, CUL3)"
# [1525] "Ubiquitin E3 ligase (CUL1, RBX1, SKP1)"
# [1526] "Ubiquitin E3 ligase (CUL3, KLHL3, WNK1)"
# [1527] "Ubiquitin E3 ligase (CUL3, KLHL3, WNK4)"
# [1528] "Ubiquitin E3 ligase (CUL3, KLHL3)"
# [1529] "Ubiquitin E3 ligase (DDB1, CUL4A, RBX1)"
# [1530] "Ubiquitin E3 ligase (DDB1, DDB2, CUL4A, CUL4B, RBX1)"
# [1531] "Ubiquitin E3 ligase (DDB1, DYRK2, EDD, VPRBP)"
# [1532] "Ubiquitin E3 ligase (DDIT4, DDB1, BTRC, CUL4A)"
# [1533] "Ubiquitin E3 ligase (DET1, DDB1, CUL4A, RBX1, COP1)"
# [1534] "Ubiquitin E3 ligase (FBXO18, SKP1A, CUL1, RBX1)"
# [1535] "Ubiquitin E3 ligase (FBXO31, SKP1A, CUL1, RBX1)"
# [1536] "Ubiquitin E3 ligase (FBXW11, SKP1A, CUL1, RBX1)"
# [1537] "Ubiquitin E3 ligase (FBXW7, CUL1, SKP1A, RBX1)"
# [1538] "Ubiquitin E3 ligase (GLMN, FBXW8, SKP1A, RBX1)"
# [1539] "Ubiquitin E3 ligase (H2AFY, SPOP, CUL3)"
# [1540] "Ubiquitin E3 ligase (NFKBIA, FBXW11, BTRC, CUL1, SKP1A)"
# [1541] "Ubiquitin E3 ligase (NIPA, SKP1A, CUL1, RBX1)"
# [1542] "Ubiquitin E3 ligase (SIAH1, SIP, SKP1A, TBL1X)"
# [1543] "Ubiquitin E3 ligase (SKP1A, BTRC, CUL1)"
# [1544] "Ubiquitin E3 ligase (SKP1A, FBXW2, CUL1)"
# [1545] "Ubiquitin E3 ligase (SKP1A, FBXW8, CUL7, RBX1)"
# [1546] "Ubiquitin E3 ligase (SKP1A, SKP2, CUL1, CKS1B, RBX1)"
# [1547] "Ubiquitin E3 ligase (SKP1A, SKP2, CUL1, RBX1)"
# [1548] "Ubiquitin E3 ligase (SKP1A, SKP2, CUL1)"
# [1549] "Ubiquitin E3 ligase (SMAD3, BTRC, CUL1, SKP1A, RBX1)"
# [1550] "Ubiquitin E3 ligase (SPOP, DAXX, CUL3)"
# [1551] "Ubiquitin E3 ligase (TRIM25, DDX58)"
# [1552] "Ubiquitin E3 ligase (UBADC1, RNF123)"
# [1553] "Ubiquitin E3 ligase (VHL, TCEB1, TCEB2, CUL2)"
# [1554] "Ubiquitin E3 ligase (WSB1, TCEB1, TCEB2, CUL5, RBX1)"
# [1555] "Ubiquitin ligase complex (TRAF6, TAB2, MALT1, UEV1A, BCL10)"
# [1556] "Ubiquitin-conjugating enzyme E2 (UBC13-UEV1A)"
# [1557] "Ubiquitin-protein-ligase (UBE2N, UBE2V2/MMS2)"
# [1558] "ULK1-ATG13-ATG14-PIK3C3 complex"
# [1559] "ULK1-ATG13-RB1CC1  complex"
# [1560] "ULK1-ATG13-RB1CC1-ATG101 complex"
# [1561] "ULK2-ATG13-RB1CC1 complex"
# [1562] "Upf complex (UPF1, UPF2, UPF3a)"
# [1563] "Upf complex (UPF1, UPF2, UPF3b)"
# [1564] "URI complex (Unconventional prefoldin RPB5 Interactor)"
# [1565] "USF1-USF2 complex"
# [1566] "USP1-UAF1 complex"
# [1567] "USP1-UAF1 complex"
# [1568] "USP12-UAF1 complex"
# [1569] "USP22-SAGA complex"
# [1570] "USP46-UAF1 complex"
# [1571] "UTM-SGCE-DAG1-CAV1-NOS3 complex"
# [1572] "UTX-MLL2/3 complex"
# [1573] "VAM1-VELI1 complex"
# [1574] "VASP-CXCR2 complex, CXCL8 stimulated"
# [1575] "VCP-VIMP-DERL1 complex"
# [1576] "VCP-VIMP-DERL1-DERL2-HRD1-SEL1L complex"
# [1577] "VCP-VIMP-DERL2 complex"
# [1578] "VEcad-VEGFR complex"
# [1579] "VEGF transcriptional complex"
# [1580] "VEGFA(165)-KDR-NRP1 complex"
# [1581] "VEGFR2-S1PR1-ERK1/2-PKC-alpha complex"
# [1582] "VEGFR2-S1PR2-ERK1/2-PKC-alpha complex"
# [1583] "VEGFR2-S1PR3-ERK1/2-PKC-alpha complex"
# [1584] "VEGFR2-S1PR5-ERK1/2-PKC-alpha complex"
# [1585] "VHL-TBP1-HIF1A complex"
# [1586] "VHL-TCEB1-TCEB2 complex"
# [1587] "VHL-VDU1-TCEB1-TCEB2 complex"
# [1588] "Vigilin-DNA-PK-Ku antigen complex"
# [1589] "WASH complex"
# [1590] "WASH-CAPZalpa/beta complex"
# [1591] "Wave-2 complex"
# [1592] "WDR20-USP12-UAF1 complex"
# [1593] "WDR20-USP46-UAF1 complex"
# [1594] "WHAMM-RhoD complex"
# [1595] "WICH complex"
# [1596] "WINAC complex"
# [1597] "WIP-WASp-actin-myosin-IIa complex"
# [1598] "WNK1-OSR1 complex"
# [1599] "WNK1-SPAk complex"
# [1600] "WRA complex (WDR5, RBBP5, ASH2L)"
# [1601] "WRAD  complex (WDR5, RBBP5, ASH2L, DPY30)"
# [1602] "WRN-Ku70-Ku80-PARP1 complex"
# [1603] "WRN-TRF2 complex"
# [1604] "WWTR1 homodimer"
# [1605] "WWTR1-YAP1 complex"
# [1606] "WWTR1-YWHAQ complex"
# [1607] "XFIM complex"
# [1608] "XPA-ERCC1-ERCC4 complex"
# [1609] "XRCC1-LIG3-PNK-TDP1 complex"
# [1610] "Y14-Magoh complex"
# [1611] "YWHAQ-CALM1-CABIN1 complex"
# [1612] "YY1-MDM2-p53 complex"
# [1613] "YY1-Notch1 complex"
# [1614] "YY1-Notch1-RBP-Jkappa complex"
# [1615] "ZEB2-KDM1A complex"
# [1616] "ZNF198-PML complex"
# [1617] "ZNF198-SUMO1 complex"
# [1618] "ZNF304-corepressor complex"
# [1619] "ZO1-(beta)cadherin-(VE)cadherin-VEGFR2 complex"
